# %% [markdown]
# # Exercise 02 Regression I - Simple Linear Regression

# %% [markdown]
# ## Pedagogy
#
# This notebook contains both theoretical explanations and executable cells to execute your code.
#
# When you see the <span style="color:red">**[TBC]**</span> (To Be Completed) sign, it means that you need to perform an action else besides executing the cells of code that already exist. These actions can be:
# - Complete the code with proper comments
# - Respond to a question
# - Write an analysis
# - etc.

# %% [markdown]
# ## Part 1. Simple linear regression with ordinary least squares approach
#
# This part will build a simple linear regression model with a toy dataset. The parameters (slope and y-intercept) will be estimated using the ordinary least squares approach. In this part, we will implement the ordinary least squares with only Python build-in math module, as well as the Pandas and NumPy library.

# %% [markdown]
# ### Import libraries

# %%
# import libraries
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load dataset
#
# In this exercise, we will use a small standard dataset: the [diabetes dataset](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html). Please download this dataset (.csv file) from Learn and load it use Pandas.
#
# The diabetes dataset contains the diabetes data collected from 442 patients. There are ten features (the first 10 columns) in the dataset:
# - age (age in years)
# - sex
# - bmi (body mass index)
# - bp (average blood pressure)
# - s1 (tc, total serum cholesterol)
# - s2 (ldl, low-density lipoproteins)
# - s3 (hdl, high-density lipoproteins)
# - s4 (tch, total cholesterol / HDL)
# - s5 (ltg, possibly log of serum triglycerides level)
# - s6 (glu, blood sugar level)
#
# The 11st column is the target variable, a quantitative measure of disease progression one year after baseline.

# %%
# load diabetes dataset
data_df = pd.read_csv('diabetes_dataset.csv')
data_df.head()
# Out:
#     age  sex   bmi     bp     s1     s2    s3   s4      s5    s6  target
# 0  59.0  2.0  32.1  101.0  157.0   93.2  38.0  4.0  4.8598  87.0   151.0
# 1  48.0  1.0  21.6   87.0  183.0  103.2  70.0  3.0  3.8918  69.0    75.0
# 2  72.0  2.0  30.5   93.0  156.0   93.6  41.0  4.0  4.6728  85.0   141.0
# 3  24.0  1.0  25.3   84.0  198.0  131.4  40.0  5.0  4.8903  89.0   206.0
# 4  50.0  1.0  23.0  101.0  192.0  125.4  52.0  4.0  4.2905  80.0   135.0

# %% [markdown]
# ### Explore the dataset
#
# In this exercise, we want to build a simple linear regression model to predict the target variable (the quantitative measure of disease progression one year after baseline) for diabetes patients.
#
# As we are using the simple linear regression as the regression algorithm, we need to select a single input variable from the 10 features. We can compare the correlations between different features and the target variable and select the feature with the strongest correlation as the input variable.

# %%
# calculate the correlation matrix for all columns in the dataset
corr = data_df.corr()
corr
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#               s4        s5        s6    target
# age     0.203841  0.270774  0.301731  0.187889
# sex     0.332115  0.149916  0.208133  0.043062
# bmi     0.413807  0.446157  0.388680  0.586450
# bp      0.257650  0.393480  0.390430  0.441482
# s1      0.542207  0.515503  0.325717  0.212022
# s2      0.659817  0.318357  0.290600  0.174054
# s3     -0.738493 -0.398577 -0.273697 -0.394789
# s4      1.000000  0.617859  0.417212  0.430453
# s5      0.617859  1.000000  0.464669  0.565883
# s6      0.417212  0.464669  1.000000  0.382483
# target  0.430453  0.565883  0.382483  1.000000

# %% [markdown]
# The last row of the correlation matrix shows the correlations between different features and the target variable. We can find that the third feature, bmi, has the strongest correlation.
#
# We can also set different background colors for the cells according to the strength of the correlation to make it more intuitive.

# %%
# show correlation matrix with background colors
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_b40c7_row0_col0, #T_b40c7_row1_col1, #T_b40c7_row2_col2, #T_b40c7_row3_col3, #T_b40c7_row4_col4, #T_b40c7_row5_col5, #T_b40c7_row6_col6, #T_b40c7_row7_col7, #T_b40c7_row8_col8, #T_b40c7_row9_col9, #T_b40c7_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b40c7_row0_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_b40c7_row0_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_b40c7_row0_col3, #T_b40c7_row4_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_b40c7_row0_col4, #T_b40c7_row1_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b40c7_row0_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_b40c7_row0_col6, #T_b40c7_row2_col5, #T_b40c7_row3_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b40c7_row0_col7, #T_b40c7_row7_col9 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_b40c7_row0_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_b40c7_row0_col9, #T_b40c7_row3_col1, #T_b40c7_row4_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_b40c7_row0_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b40c7_row1_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b40c7_row1_col3, #T_b40c7_row4_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b40c7_row1_col4, #T_b40c7_row6_col0, #T_b40c7_row6_col1, #T_b40c7_row6_col2, #T_b40c7_row6_col3, #T_b40c7_row6_col5, #T_b40c7_row6_col7, #T_b40c7_row6_col8, #T_b40c7_row6_col9, #T_b40c7_row6_col10, #T_b40c7_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b40c7_row1_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b40c7_row1_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b40c7_row1_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b40c7_row1_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_b40c7_row1_col9, #T_b40c7_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_b40c7_row1_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_b40c7_row2_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b40c7_row2_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b40c7_row2_col3, #T_b40c7_row8_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_b40c7_row2_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b40c7_row2_col6, #T_b40c7_row3_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b40c7_row2_col7 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_b40c7_row2_col8 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_b40c7_row2_col9, #T_b40c7_row3_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b40c7_row2_col10 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_b40c7_row3_col2, #T_b40c7_row9_col10 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_b40c7_row3_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b40c7_row3_col6, #T_b40c7_row8_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b40c7_row3_col7, #T_b40c7_row7_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_b40c7_row3_col8 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b40c7_row3_col10 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b40c7_row4_col0, #T_b40c7_row5_col3, #T_b40c7_row5_col6, #T_b40c7_row10_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b40c7_row4_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b40c7_row4_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_b40c7_row4_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_b40c7_row4_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_b40c7_row4_col8 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b40c7_row4_col9 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b40c7_row5_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b40c7_row5_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b40c7_row5_col4 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b40c7_row5_col7 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_b40c7_row5_col8, #T_b40c7_row10_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b40c7_row5_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b40c7_row5_col10, #T_b40c7_row9_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b40c7_row6_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b40c7_row7_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b40c7_row7_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b40c7_row7_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b40c7_row7_col4, #T_b40c7_row10_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_b40c7_row7_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_b40c7_row7_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_b40c7_row7_col10 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_b40c7_row8_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b40c7_row8_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_b40c7_row8_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_b40c7_row8_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b40c7_row8_col6, #T_b40c7_row10_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b40c7_row8_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_b40c7_row8_col9 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_b40c7_row8_col10, #T_b40c7_row10_col8 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_b40c7_row9_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b40c7_row9_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b40c7_row9_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b40c7_row9_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_b40c7_row9_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b40c7_row9_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b40c7_row9_col7 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_b40c7_row9_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_b40c7_row10_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b40c7_row10_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b40c7_row10_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b40c7_row10_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_b40c7_row10_col7 {
#   background-color: #f7b599;
#   color: #000000;
# }
# </style>
# <table id="T_b40c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b40c7_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_b40c7_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_b40c7_level0_col2" class="col_heading level0 col2" >bmi</th>
#       <th id="T_b40c7_level0_col3" class="col_heading level0 col3" >bp</th>
#       <th id="T_b40c7_level0_col4" class="col_heading level0 col4" >s1</th>
#       <th id="T_b40c7_level0_col5" class="col_heading level0 col5" >s2</th>
#       <th id="T_b40c7_level0_col6" class="col_heading level0 col6" >s3</th>
#       <th id="T_b40c7_level0_col7" class="col_heading level0 col7" >s4</th>
#       <th id="T_b40c7_level0_col8" class="col_heading level0 col8" >s5</th>
#       <th id="T_b40c7_level0_col9" class="col_heading level0 col9" >s6</th>
#       <th id="T_b40c7_level0_col10" class="col_heading level0 col10" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b40c7_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_b40c7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b40c7_row0_col1" class="data row0 col1" >0.173737</td>
#       <td id="T_b40c7_row0_col2" class="data row0 col2" >0.185085</td>
#       <td id="T_b40c7_row0_col3" class="data row0 col3" >0.335428</td>
#       <td id="T_b40c7_row0_col4" class="data row0 col4" >0.260061</td>
#       <td id="T_b40c7_row0_col5" class="data row0 col5" >0.219243</td>
#       <td id="T_b40c7_row0_col6" class="data row0 col6" >-0.075181</td>
#       <td id="T_b40c7_row0_col7" class="data row0 col7" >0.203841</td>
#       <td

# %% [markdown]
# By comparint the correlations between different features and the target variable, we can select bmi as the input variable for our simple linear regression model.

# %% [markdown]
# ### Split training and testing dataset
#
# We need to split the dataset into two parts: the training and testing dataset. The training dataset will be used to train the simple linear regression model. The testing dataset will be used to evaluate the learned model.
#
# The proportions of training and test sets can vary. Here we use 50% of the data as the training set and the rest data as the test set.

# %%
# get the total amount of the data
print("The dataset contains a total of {} instances of data.".format(len(data_df)))
# Out:
# The dataset contains a total of 442 instances of data.

# %%
# split the training and testing set
train_ratio = 0.5
train_df = data_df[:int(train_ratio * len(data_df))]
test_df = data_df[int(train_ratio * len(data_df)):]

# %%
# extract the input and target variables
X_train, y_train = train_df['bmi'].values, train_df['target'].values
X_test, y_test = test_df['bmi'].values, test_df['target'].values

# %%
# visualize the training and testing set
plt.figure(figsize = [5, 4])
plt.plot(X_train, y_train, '.', label = 'train')
plt.plot(X_test, y_test, '.', label = 'test')
plt.xlabel('bmi')
plt.ylabel('target')
plt.legend()
plt.show()

# %% [markdown]
# ### Ordinary least squares approach
#
# We will use the ordinary least squares approach to estimate the slope and y-intercept parameter for the simple linear regression model.
#
# $\hat{\beta}_1=\frac{S_{xy}}{S_{xx}}$
#
# $\hat{\beta}_0=\bar{y}-\hat{\beta}_1\bar{x}$
#
# $\bar{x}=\frac{1}{n}\sum_{i=1}^nx_i$
#
# $\bar{y}=\frac{1}{n}\sum_{i=1}^ny_i$
#
# $S_{xx}=\frac{1}{n-1}\sum(x_i-\bar{x})^2$
#
# $S_{xy}=\frac{1}{n-1}\sum(x_i-\bar{x})(y_i-\bar{y})$

# %%
# calculate the average of x and y
X_mean = X_train.mean()
y_mean = y_train.mean()

# %%
# calculate Sxy and Sxx
S_xx = np.square((X_train - X_mean)).sum() / (len(X_train) - 1)
S_xy = ((X_train - X_mean) * (y_train - y_mean)).sum() / (len(X_train) - 1)

# %%
# calculate the slope and y-intercept
slope = S_xy / S_xx
y_intercept = y_mean - slope * X_mean
print('The value of the slope is:', slope)
print('The value of the y-intercept is:', y_intercept)
# Out:
# The value of the slope is: 9.856096036094776
# The value of the y-intercept is: -109.91157469331546

# %%
# visulalize the learned model
plt.figure(figsize = [5, 4])
plt.plot(X_train, y_train, '.', label = 'training data')
plt.plot(X_train, y_intercept + slope * X_train, '-', label = 'SLR model')
plt.xlabel('bmi')
plt.ylabel('target')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate the model with testing set
#
# Once we obtained the slope and y-intercept of the simple linear regression model using the training dataset, we can evaluate the learned model using the testing dataset.

# %%
# use the learned model to make predictions on the test set
y_pred = y_intercept + slope * X_test
print(y_pred)
# Out:
# [114.80741493 126.63473017 128.60594938  89.18156524 179.85764877
#  107.9081477  122.69229176 138.46204542 135.50521661 215.3395945
#  121.70668215 150.28936066 183.80008718 185.77130639 136.49082621
#  156.20301828  87.21034603 141.41887423 168.03033352 218.29642331
#  142.40448383 128.60594938 107.9081477  199.56984084 117.76424374
#  120.72107255  75.38303079 193.65618322 205.48349846 201.54106005
#  239.97983459 204.49788886 180.84325837 201.54106005  90.16717484
#  297.1451916   99.03766127 127.62033978 116.77863414 142.40448383
#  111.85058612 266.59129389  79.3254692  175.91521035 126.63473017
#   93.12400365 149.30375106 231.10934816 120.72107255 177.88642956
#  158.17423749 156.20301828 131.56277819 127.62033978 139.44765502
#  173.94399115  96.08083246 116.77863414 127.62033978 167.04472392
#   67.49815396 145.36131264 101.99449008 129.59155898 131.56277819
#  100.02327088 144.37570304 134.519607   200.55545044 220.26764252
#  167.04472392 129.59155898 235.05178657 121.70668215 185.77130639
#   94.10961325 142.40448383 115.79302453 137.47643581 217.31081371
#  127.62033978 180.84325837 181.82886798 114.80741493 113.82180533
#  148.31814145 121.70668215 107.9081477  151.27497026 209.42593688
#  186.75691599 128.60594938 198.58423124 186.75691599 131.56277819
#  163.10228551 118.74985334 156.20301828 154.23179907 177.88642956
#  197.59862163 206.46910807 143.39009343 155.21740868 199.56984084
#  142.40448383 254.76397864 211.39715608  99.03766127 177.88642956
#  126.63473017 245.89349221 144.37570304 106.9225381  105.9369285
#  228.15251934 138.46204542 119.73546295 143.39009343 137.47643581
#  204.49788886 170.00155273 167.04472392 139.44765502 147.33253185
#  166.05911432 122.69229176 131.56277819  97.06644206 205.48349846
#  112.83619572  84.25351722  99.03766127 191.68496401 141.41887423
#  119.73546295 195.62740243  72.42620197 155.21740868 169.01594313
#  143.39009343 245.89349221 127.62033978 144.37570304 114.80741493
#  275.46178032 306.01567803 152.26057987 184.78569679  97.06644206
#  141.41887423 128.60594938 140.43326462 118.74985334 147.33253185
#  212.38276569 159.15984709 152.26057987 114.80741493 173.94399115
#   68.48376356 205.48349846 123.67790136 122.69229176 132.54838779
#  112.83619572 164.08789511 127.62033978 151.27497026 213.36837529
#   86.22473642 122.69229176 107.9081477  167.04472392 151.27497026
#  121.70668215 146.34692225 164.08789511 170.98716234 191.68496401
#  108.89375731 119.73546295 238.99422498 199.56984084 262.64885547
#   76.36864039 235.05178657 103.96570929 139.44765502 124.66351097
#  203.51227925 228.15251934 149.30375106 156.20301828 158.17423749
#  223.22447133 215.3395945  127.62033978 100.02327088 116.77863414
#  165.07350471 221.25325212 113.82180533 160.1454567  112.83619572
#  118.74985334 155.21740868 231.10934816 119.73546295  98.05205167
#  121.70668215 200.55545044  95.09522286 151.27497026 128.60594938
#   82.28229801 168.03033352 135.50521661 135.50521661 185.77130639
#   83.26790761]

# %%
# visualize the predictions
plt.figure(figsize = [5, 4])
plt.plot(y_test, y_pred, '.')
plt.plot(y_test, y_test, 'r-', label = 'one-to-one line')
plt.xlabel('target value')
plt.ylabel('predicted value')
plt.legend()
plt.show()

# %% [markdown]
# As can be seen from the figure above, the scattered points are distributed near the one-to-one line. This indicates that the simple linear regression model can somehow predict the progression of diabetes by a patient's BMI.
#
# Apart from the visualization, we can use different metrics to evaluate the model quantitatively. Here we will calculate the MSE (mean squared error), RMSE (root mean squared error) and $R^2$ (the coefficient of determination) to evaluate the regression model.

# %%
# calculate mse
mse_test = np.square(y_test - y_pred).mean()
print("The MSE on the testing dataset is:", mse_test)
# Out:
# The MSE on the testing dataset is: 3878.729958668522

# %%
# calculate rmse
rmse_test = math.sqrt(mse_test)
print("The RMSE on the testing dataset is:", rmse_test)
# Out:
# The RMSE on the testing dataset is: 62.27945053280835

# %%
# claculate r^2
r2_test = 1 - np.square(y_test - y_pred).sum() / np.square(y_test - y_test.mean()).sum()
print("The R2 score on the testing dataset is:", r2_test)
# Out:
# The R2 score on the testing dataset is: 0.37410885207201106

# %% [markdown]
# ## Part 2. Simple linear regression with `scikit-learn`
#
# In this part, we will rebuild the above simple linear regression model using `scikit-learn`. More specifically, we will use `sklearn.linear_model.LinearRegression()` to fit a simple linear regression model on the same diabetes dataset.
#
# `sklearn.linear_model.LinearRegression()` also use the ordinary least squares approach to estimate the slope and y-intercept. However, instead of using hand-coded programs, `scikit-learn` offers a lot of API to implement the machine learning process quickly and easily.

# %% [markdown]
# ### Import libraries

# %%
# import libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Load dataset
#
# Use `sklearn.datasets.load_diabetes` to load the same diabetes dataset.

# %%
# load diabetes dataset
feature_df, target_df = datasets.load_diabetes(return_X_y = True, as_frame = True, scaled = False)
# Feature and target related to the dependent and independent variable of the regresion
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
# show the head of the feature_df
feature_df.head()
# Out:
#     age  sex   bmi     bp     s1     s2    s3   s4      s5    s6
# 0  59.0  2.0  32.1  101.0  157.0   93.2  38.0  4.0  4.8598  87.0
# 1  48.0  1.0  21.6   87.0  183.0  103.2  70.0  3.0  3.8918  69.0
# 2  72.0  2.0  30.5   93.0  156.0   93.6  41.0  4.0  4.6728  85.0
# 3  24.0  1.0  25.3   84.0  198.0  131.4  40.0  5.0  4.8903  89.0
# 4  50.0  1.0  23.0  101.0  192.0  125.4  52.0  4.0  4.2905  80.0

# %%
# show the head of the target_df
target_df.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: target, dtype: float64

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Read the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html#sklearn.datasets.load_diabetes) of `sklearn.datasets.load_diabetes()`. Explain the meaning of the parameters: `return_X_y`, `as_frame`, `scaled`.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# ### Split training and testing dataset
#
# `scikit-learn` offers the `sklearn.model_selection.train_test_split()` function to split the dataset into the training and testing part.

# %%
# eliminate features other than bmi
feature_df = feature_df['bmi']

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(feature_df.values, target_df.values, train_size = 0.5, shuffle = False)

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Read the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html#sklearn.model_selection.train_test_split) of `sklearn.model_selection.train_test_split()`. Explain the meaning of the parameters: `train_size`, `shuffle`.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# ### Fit the model
#
# Use `sklearn.linear_model.LinearRegression` to fit the simple linear regression model on the training dataset.

# %%
# fit the model
slr = LinearRegression(fit_intercept = True)
slr.fit(X_train.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
# print the learned slope and y_intercept
print('The value of the slope is:', slr.coef_[0])
print('The value of the y-intercept is:', slr.intercept_)
# Out:
# The value of the slope is: 9.856096036094778
# The value of the y-intercept is: -109.91157469331552

# %% [markdown]
# Did you get the same model as in Part 1?

# %%
# visulalize the learned model
plt.figure(figsize = [5, 4])
plt.plot(X_train, y_train, '.', label = 'training data')
plt.plot(X_train, slr.intercept_ + slr.coef_[0] * X_train, '-', label = 'SLR model')
plt.xlabel('bmi')
plt.ylabel('target')
plt.legend()
plt.show()

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Read the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression) of `sklearn.linear_model.LinearRegression()`. Explain the meaning of the parameters `fit_intercept`, the method `fit()`, and the attributes `coef_` and `intercept_`.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# ### Evaluate the model with testing set
#
# Similarly, the SLR model built with `scikit-learn` offers the `predict()` method to make predictions on new data. `scikit-learn` also provides a series of build-in [regression metrics](https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics) for evaluation purpose.

# %%
# use the learned model to make predictions on the test set
y_pred = slr.predict(X_test.reshape(-1, 1))

# %%
# visualize the predictions
plt.figure(figsize = [5, 4])
plt.plot(y_test, y_pred, '.')
plt.plot(y_test, y_test, 'r-', label = 'one-to-one line')
plt.xlabel('target value')
plt.ylabel('predicted value')
plt.legend()
plt.show()

# %%
# calculate mse
mse_test = mean_squared_error(y_test, y_pred, squared = True)
print("The MSE on the testing dataset is:", mse_test)
# Out:
# The MSE on the testing dataset is: 3878.729958668523

# %%
# calculate rmse
rmse_test = mean_squared_error(y_test, y_pred, squared = False)
print("The RMSE on the testing dataset is:", rmse_test)
# Out:
# The RMSE on the testing dataset is: 62.279450532808355

# %%
# claculate r^2
r2_test = r2_score(y_test, y_pred)
print("The R2 score on the testing dataset is:", r2_test)
# Out:
# The R2 score on the testing dataset is: 0.37410885207201094

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Read the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression) of `sklearn.linear_model.LinearRegression()`. Explain the meaning of the method `predict()`.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Read the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn.metrics.mean_squared_error) of `sklearn.metrics.mean_squared_error()`. Explain the meaning of the paramter `squared`.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# ## Part 3. Hands-on exercise with a real-world dataset
#
# In this exercise, we will build a regression model with the simple least regression algorithm for a real-world dataset, the [California Housing dataset](https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset).
#
# This dataset was obtained from the StatLib repository. https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household.
#
# <span style="color:red">**[TBC]**</span> Please complete the following tasks:
#
# - Load the California Housing Dataset
# - Explore the dataset
# - Pre-process the dataset
# - Build the simple linear regression model
# - Evaluate the learned SLR model

# %% [markdown]
# ### Task 1. Load the California Housing Dataset
#
# <span style="color:red">**[TBC]**</span> It can be downloaded/loaded using the `sklearn.datasets.fetch_california_housing()` function.

# %%
# [TBC] complete your code here with proper comments
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# load diabetes dataset
from sklearn.datasets import fetch_california_housing

# Fetch the California housing dataset
data_df = fetch_california_housing()

# The dataset is a Bunch object
# You can see the available keys with the .keys() method
print(data_df.keys())

# You can access the features with .data
print(data_df.data)

# And the target values with .target
print(data_df.target)
#feature_df, target_df = datasets.load_california(return_X_y = True, as_frame = True, scaled = False)
# Feature and target related to the dependent and independent variable of the regresion
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Please explain why you chose the parameter values for the `sklearn.datasets.fetch_california_housing` function and what they do.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# ### Task 2. Explore the dataset
#
# You will explore the dataset to get a better understanding of the dataset. The final goal is to select the single input feature for building the SLR model.
#
# <span style="color:red">**[TBC]**</span> First, create a synthetical data frame called `data_df` with both features and target.

# %%
# [TBC] complete your code here with proper comments
# feature_df, target_df = datasets.data_df(return_X_y = True, as_frame = True, scaled = False)
# Create a DataFrame for the features
feature_df = pd.DataFrame(data.data, columns=data.feature_names)

# Create a DataFrame for the target
target_df = pd.DataFrame(data.target, columns=["Target"])

print(feature_df.head())
print(target_df.head())

# Feature and target related to the dependent and independent variable of the regresion
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
#    Target
# 0   4.526
# 1   3.585
# 2   3.521
# 3   3.413
# 4   3.422

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Find out how many rows there are in the dataset.

# %%
# [TBC] complete your code here with proper comments
num_rows = feature_df.shape[0]
print(f'The dataset has {num_rows} rows.')
# Out:
# The dataset has 20640 rows.

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Explain what information the number of rows in the dataset represents.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# The number of rows represent the quantity of registers or data registred we had on the dataset of California
#
# In this code, feature_df.shape[0] returns the number of rows in the DataFrame feature_df. The shape attribute returns a tuple where the first element is the number of rows and the second element is the number of columns. So, feature_df.shape[0] gives the number of rows and feature_df.shape[1] would give the number of columns. The print statement then prints out the number of rows in the dataset.

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Find out how many columns there are in the dataset and and what is the name of each column.

# %%
# [TBC] complete your code here with proper comments

num_columns = feature_df.shape[1]
print(f'The dataset has {num_columns} columns.')
# Out:
# The dataset has 8 columns.

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Explain the meaning of the variables represented by each column.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# Here’s a simple explanation of the columns in the California housing dataset:
#
# MedInc: This is the median income in the block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data. It typically has a population of 600 to 3,000 people.
#
# HouseAge: This is the median house age in the block group.
#
# AveRooms: This is the average number of rooms per household.
#
# AveBedrms: This is the average number of bedrooms per household.
#
# Population: This is the total population in the block group.
#
# AveOccup: This is the average number of household members.
#
# Latitude: This is the block group’s latitude

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Explore the statistics for each column.
#
# Tips:
# - You can use [`pd.DataFrame.describe()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html#pandas.DataFrame.describe) to get descriptive statistics for each column.
# - You can also use [`pd.DataFrame.hist()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html#pandas.DataFrame.hist) to plot the hisrograms for each column to visualize its distribution.

# %%
# [TBC] complete you code here with comments
# Create a DataFrame for the features
feature_df = pd.DataFrame(data.data, columns=data.feature_names)

# Use describe() to get statistics for each column
print(feature_df.describe())

# Use hist() to create a histogram for each column
feature_df.hist(bins=50, figsize=(20,15))
plt.show()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Describe your findings from the above descriptive statistics.
#
# <span style="color:red">**[TBC]**</span> Complete your answer here.

# %% [markdown]
# Looking at the graphics it can be seen the different distribution of data, the most interesting is the distribution of MedInc that are cumulated to the left. Regarding to the other columns it is not a clear pattern on the distributions

# %% [markdown]
# <span style="color:red">**[TBC]**</span> Select a single input variable from the available features. Compare the correlations between different features and the target variable and select the feature with the strongest correlation as the input variable.
#
# <span style="color:red">**[TBC]**</span> Which feature did you select? Write your answer here.

# %% [markdown]
# Theres an strong correlation between AveRooms and AveBedrms, because when it is more rooms in a house, the quantity of bedreooms needed increased
#
# AveRooms: This is the average number of rooms per household.
#
# AveBedrms: This is the average number of bedrooms per household.

# %%
# [TBC] complete your code here with proper comments

import seaborn as sns
# Create a DataFrame for the features
feature_df = pd.DataFrame(data.data, columns=data.feature_names)

# Add target to the DataFrame
feature_df['Target'] = data.target

# Calculate the correlation matrix
corr_matrix = feature_df.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

"""
# calculate the correlation matrix for all columns in the dataset
corr = data_df.corr()
corr

# show correlation matrix with background colors
corr.style.background_gradient(cmap = 'coolwarm')
"""
# Out:
# "\n# calculate the correlation matrix for all columns in the dataset\ncorr = data_df.corr()\ncorr\n\n# show correlation matrix with background colors\ncorr.style.background_gradient(cmap = 'coolwarm')\n"

# %%
# calculate the correlation matrix for all columns in the dataset\ncorr = data_df.corr()\ncorr\n\n
# show correlation matrix with background colors\ncorr.style.background_gradient(cmap = 'coolwarm')\n"

# %% [markdown]
# ### Task 3. Pre-process the dataset
#
# <span style="color:red">**[TBC]**</span> Please split the whold dataset into two parts: the training and testing set. Please use 70% of the data as the training dataset, and the rest as the testing dataset.

# %%
# [TBC] complete your code here with proper comments
# Create a DataFrame for the features
features = pd.DataFrame(data.data, columns=data.feature_names)

# Create a DataFrame for the target
target = pd.DataFrame(data.target, columns=["Target"])

# Split the data into training and testing sets
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.3, random_state=42)

print(f'Training set has {features_train.shape[0]} rows')
print(f'Testing set has {features_test.shape[0]} rows')
# Out:
# Training set has 14448 rows
# Testing set has 6192 rows

# %% [markdown]
# ### Task 4. Build the SLR model
#
# <span style="color:red">**[TBC]**</span> Please complete the following steps:
#
# - Fit the model with the training dataset
# - Print the value of slope and y-intercept
# - Visualize the learned model

# %%
# [TBC] complete your code here with proper comments
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# Fit the model with the training dataset
model = LinearRegression()
model.fit(features_train[['MedInc']], target_train)

# Print the value of slope and y-intercept
print(f"Slope: {model.coef_[0]}")
print(f"Y-intercept: {model.intercept_}")

# Visualize the learned model
plt.scatter(features_train[['MedInc']], target_train, color='blue')
plt.plot(features_train[['MedInc']], model.predict(features_train[['MedInc']]), color='red')
plt.title('Linear Regression Model')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()
# Out:
# Slope: [0.41819327]
# Y-intercept: [0.44794966]

# %% [markdown]
# ### Task 5. Evaluate the learned SLR model
#
# <span style="color:red">**[TBC]**</span> Please complete the following steps:
#
# - Use the learned model to make predictions on the testing dataset
# - Visualize the predictions
# - Calculate quantitative metrics for evaluation: MSE, RMSE, $R^2$

# %%
# [TBC] complete your code here with proper comments
from sklearn.metrics import mean_squared_error, r2_score

# Use the learned model to make predictions on the testing dataset
predictions = model.predict(features_test[['MedInc']])

# Visualize the predictions
plt.scatter(features_test[['MedInc']], target_test, color='blue')
plt.plot(features_test[['MedInc']], predictions, color='red')
plt.title('Predictions vs. Actual')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Calculate quantitative metrics for evaluation
mse = mean_squared_error(target_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(target_test, predictions)

print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R^2: {r2}")
# Out:
# MSE: 0.6917979868048499
# RMSE: 0.8317439430526982
# R^2: 0.47293192589970245

# %% [markdown]
# ### Challenge 1. Eliminate capped data and rebuild the model
#
# As can be seen from the result figure, the `MedHouseVal` seems to have an upper limit near 5. Check the descriptive statictics using `pd.DataFrame.describe()`, we can find that the maximum value of `MedHouseVal` is 5.00001.
#
# This capping may be caused by different reasons:
# - Capping the values can be a way to ensure privacy, as very high values could potentially be used to identify individual properties or owners, especially if combined with other information.
# - Sometimes, values are capped during the data entry process to prevent the effects of possible data collection or entry errors.
#
# Although we don't know the specific reason, such capped data does not reflect the true situation of housing prices.
#
# Try to eliminate thes capped data from the dataset and rebuild the SLR model. Evaluate the new model with different metrics, Can you get a better model? Different metrics may give you different conclusions.
#
# <span style="color:red">**[TBC]**</span> This challenge won't be evaluated and counted towards your grade. You may submit this assignment without solving this challenge. However, leaving this part blank is not allowed. Try to complete the code even if it doesn't meet the requirements.

# %%
# [TBC] complete your code here with proper comments
# Fetch the California housing dataset
data = fetch_california_housing()

# Create a DataFrame for the features
features = pd.DataFrame(data.data, columns=data.feature_names)

# Create a DataFrame for the target
target = pd.DataFrame(data.target, columns=["Target"])

# Remove capped data
mask = target['Target'] < 5
features, target = features[mask], target[mask]

# Split the data into training and testing sets
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fit the model with the training dataset
model = LinearRegression()
model.fit(features_train[['MedInc']], target_train)

# Print the value of slope and y-intercept
print(f"Slope: {model.coef_[0]}")
print(f"Y-intercept: {model.intercept_}")

# Visualize the learned model
plt.scatter(features_train[['MedInc']], target_train, color='blue')
plt.plot(features_train[['MedInc']], model.predict(features_train[['MedInc']]), color='red')
plt.title('Linear Regression Model')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Use the learned model to make predictions on the testing dataset
predictions = model.predict(features_test[['MedInc']])

# Visualize the predictions
plt.scatter(features_test[['MedInc']], target_test, color='blue')
plt.plot(features_test[['MedInc']], predictions, color='red')
plt.title('Predictions vs. Actual')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Calculate quantitative metrics for evaluation
mse = mean_squared_error(target_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(target_test, predictions)

print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R^2: {r2}")
# Out:
# Slope: [0.40017387]
# Y-intercept: [0.45121829]
# MSE: 0.554124372175319
# RMSE: 0.7443953063899039
# R^2: 0.41259564269650484

# %% [markdown]
# ### Challenge 2. Build two SLR models for the two types of block groups.
#
# As discussed above, for block groups with few households and many empty houses, such as vacation resorts, the values of `AveRooms`, `AveBedrms`, and `AveOccup` can be surprisingly large.
#
# House prices in such block groups may be affected by different factors than those in regular block groups.
#
# Therefore, we want to split the dataset into two parts according to the types of block groups: one part for the block groups with few households and many empty houses, another part for the rest.
#
# We can try to build two SLR models for each to see if we can get better prediction models. To be note, for the block groups with few households and many empty houses, the `MedInc` may not be the best input feature.
#
# <span style="color:red">**[TBC]**</span> This challenge won't be evaluated and counted towards your grade. You may submit this assignment without solving this challenge. However, leaving this part blank is not allowed. Try to complete the code even if it doesn't meet the requirements.

# %%
# [TBC] complete your code here with proper comments
"""Data set and model: for the block groups with few households and many empty houses"""

# Fetch the California housing dataset
data = fetch_california_housing()

# Create a DataFrame for the features
features = pd.DataFrame(data.data, columns=data.feature_names)

# Create a DataFrame for the target
target = pd.DataFrame(data.target, columns=["Target"])

# Define "few households" as less than the median number of households
median_households = features['AveOccup'].median()
mask_few_households = features['AveOccup'] < median_households

# Define "many empty houses" as more than the median number of rooms
median_rooms = features['AveRooms'].median()
mask_many_empty_houses = features['AveRooms'] > median_rooms

# Apply the masks to the features and target
mask = mask_few_households & mask_many_empty_houses
features_few_empty, target_few_empty = features[mask], target[mask]

# Split the data into training and testing sets
features_train, features_test, target_train, target_test = train_test_split(features_few_empty, target_few_empty, test_size=0.3, random_state=42)

# Fit the model with the training dataset
model = LinearRegression()
model.fit(features_train[['MedInc']], target_train)

# Print the value of slope and y-intercept
print(f"Slope: {model.coef_[0]}")
print(f"Y-intercept: {model.intercept_}")

# Visualize the learned model
plt.scatter(features_train[['MedInc']], target_train, color='blue')
plt.plot(features_train[['MedInc']], model.predict(features_train[['MedInc']]), color='red')
plt.title('Linear Regression Model')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Use the learned model to make predictions on the testing dataset
predictions = model.predict(features_test[['MedInc']])

# Visualize the predictions
plt.scatter(features_test[['MedInc']], target_test, color='blue')
plt.plot(features_test[['MedInc']], predictions, color='red')
plt.title('Predictions vs. Actual')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Calculate quantitative metrics for evaluation
mse = mean_squared_error(target_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(target_test, predictions)

print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R^2: {r2}")
# Out:
# Slope: [0.49819756]
# Y-intercept: [0.17367569]
# MSE: 0.7703475014923187
# RMSE: 0.8776944237559668
# R^2: 0.5711581410043532

# %%
"""Data set and model: for the block groups with the rest"""

# Fetch the California housing dataset
data = fetch_california_housing()

# Create a DataFrame for the features
features = pd.DataFrame(data.data, columns=data.feature_names)

# Create a DataFrame for the target
target = pd.DataFrame(data.target, columns=["Target"])

"""Define the opposite group"""
# Define "few households" as less than the median number of households
median_households = features['AveOccup'].median()
mask_few_households = features['AveOccup'] > median_households

# Define "many empty houses" as more than the median number of rooms
median_rooms = features['AveRooms'].median()
mask_many_empty_houses = features['AveRooms'] < median_rooms

# Apply the masks to the features and target
mask = mask_few_households & mask_many_empty_houses
features_few_empty, target_few_empty = features[mask], target[mask]

# Split the data into training and testing sets
features_train, features_test, target_train, target_test = train_test_split(features_few_empty, target_few_empty, test_size=0.3, random_state=42)

# Fit the model with the training dataset
model = LinearRegression()
model.fit(features_train[['MedInc']], target_train)

# Print the value of slope and y-intercept
print(f"Slope: {model.coef_[0]}")
print(f"Y-intercept: {model.intercept_}")

# Visualize the learned model
plt.scatter(features_train[['MedInc']], target_train, color='blue')
plt.plot(features_train[['MedInc']], model.predict(features_train[['MedInc']]), color='red')
plt.title('Linear Regression Model')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Use the learned model to make predictions on the testing dataset
predictions = model.predict(features_test[['MedInc']])

# Visualize the predictions
plt.scatter(features_test[['MedInc']], target_test, color='blue')
plt.plot(features_test[['MedInc']], predictions, color='red')
plt.title('Predictions vs. Actual')
plt.xlabel('Median Income')
plt.ylabel('Target')
plt.show()

# Calculate quantitative metrics for evaluation
mse = mean_squared_error(target_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(target_test, predictions)

print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R^2: {r2}")
# Out:
# Slope: [0.29942452]
# Y-intercept: [0.64108262]
# MSE: 0.30486840465123505
# RMSE: 0.5521488971746978
# R^2: 0.2366703866174189
